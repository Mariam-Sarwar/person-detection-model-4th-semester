# %%
import os

if 'COLAB_GPU'in os.environ:
  print("GPU IS ENABLED")
else:
    print ("GPU IS NOT ENABLED")
# Out:
# GPU IS ENABLED

# %%
# !python --version
# Out:
# Python 3.11.12

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 58.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 57.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 32.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 56.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import  ultralytics
ultralytics.checks ()
# Out:
# Ultralytics 8.3.132 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.4/112.6 GB disk)

# %%
# !python --version
# Out:
# Python 3.11.12

# %%
# %pwd
# Out:
# '/content'

# %%
# !mkdir peopledetection

# %%
# !ls
# Out:
# drive  peopledetection

# %%
path ="/content/peopledetection"

# %%
# %pwd
# Out:
# '/content'

# %%
os.chdir("/content/peopledetection")
# %pwd
# Out:
# '/content/peopledetection'

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="PVZd94G7nsPsPj5OMvsl")
project = rf.workspace("leo-ueno").project("people-detection-o4rdr")
version = project.version(8)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 111.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to People-Detection-8 in yolov8:: 100%|██████████| 34814/34814 [00:10<00:00, 3277.36it/s]

# %%
os.chdir("/content/peopledetection/People-Detection-8")

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml 'epochs=10' 'imgsz=640' 'batch=16'
# Out:
# Ultralytics 8.3.132 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
 # !ls '/content/peopledetection/People-Detection-8/runs/detect/train2/weights'
# Out:
# best.pt  last.pt

# %%
resultData = "/content/peopledetection/People-Detection-8/runs/detect/train2"
from IPython.display import Image, display
Image(filename = f'{resultData}/confusion_matrix.png')

# %%
Image(filename = f'{resultData}/results.png')

# %%
import pandas as pd
df = pd.read_csv(f'{resultData}/results.csv')

# %%
print(df.head(5))
# Out:
#    epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      1   348.523         1.53355         1.61541         1.34188
# 1      2   689.573         1.58778         1.47599         1.40527
# 2      3  1021.030         1.54447         1.40539         1.38136
# 3      4  1358.630         1.48708         1.33315         1.35034
# 4      5  1696.730         1.42446         1.25047         1.31133
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0               0.61906            0.44343           0.46789
# 1               0.64651            0.44568           0.47385
# 2               0.62972            0.44934           0.48641
# 3               0.67628            0.49212           0.54688
# 4               0.70045            0.48265           0.55202
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0              0.22530       1.65869       1.48721       1.48454  0.000666
# ...

# %%
print(df.tail(1))
# Out:
#    epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 9     10  3364.39         1.18727         0.97183         1.17497
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 9               0.75265            0.56492           0.64721
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 9              0.37127        1.3066       0.92372       1.22767  0.000218
#
#      lr/pg1    lr/pg2
# 9  0.000218  0.000218

# %% [markdown]
# **video  model training**

# %%
# %pwd
# Out:
# '/content/peopledetection/People-Detection-8'

# %%
os.chdir("/content")

# %%
# !mkdir manualtestingData

# %%
import os
os.chdir("/content/manualtestingData") # Changing to the correct directory path.

# %%
# !pip install gdown
# !gdown https://drive.google.com/uc?id=1dc9uQccQfforSYMr_lJDCMoVvIsFGc3S
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1dc9uQccQfforSYMr_lJDCMoVvIsFGc3S
# To: /content/manualtestingData/3197808-hd_1920_1080_25fps.mp4
# 100% 6.24M/6.24M [00:00<00:00, 13.4MB/s]

# %%
id = '1dc9uQccQfforSYMr_lJDCMoVvIsFGc3S'
url_base = 'https://docs.google.com/uc?export=download&id='
# !wget --no-check-certificate {url_base}{id} -O inputVideo1.mp4
# Out:
# /bin/bash: line 1: -O: command not found
# --2025-05-12 16:32:00--  https://docs.google.com/uc?export=download
# Resolving docs.google.com (docs.google.com)... 74.125.68.100, 74.125.68.113, 74.125.68.138, ...
# Connecting to docs.google.com (docs.google.com)|74.125.68.100|:443... connected.
# HTTP request sent, awaiting response... 400 Bad Request
# 2025-05-12 16:32:00 ERROR 400: Bad Request.

# %%
weightsPath="/content/peopledetection/People-Detection-8/runs/detect/train2/weights"
# !yolo task=detect mode=predict model={weightsPath}/best.pt conf=.25 source =myvideo1.mp4 save=True
# Out:
# Ultralytics 8.3.132 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/240) /content/manualtestingData/myvideo1.mp4: 384x640 4 persons, 44.1ms
# video 1/1 (frame 2/240) /content/manualtestingData/myvideo1.mp4: 384x640 5 persons, 10.6ms
# video 1/1 (frame 3/240) /content/manualtestingData/myvideo1.mp4: 384x640 5 persons, 9.9ms
# video 1/1 (frame 4/240) /content/manualtestingData/myvideo1.mp4: 384x640 4 persons, 10.1ms
# video 1/1 (frame 5/240) /content/manualtestingData/myvideo1.mp4: 384x640 5 persons, 9.0ms
# video 1/1 (frame 6/240) /content/manualtestingData/myvideo1.mp4: 384x640 4 persons, 8.0ms
# video 1/1 (frame 7/240) /content/manualtestingData/myvideo1.mp4: 384x640 5 persons, 9.7ms
# video 1/1 (frame 8/240) /content/manualtestingData/myvideo1.mp4: 384x640 5 persons, 9.5ms
# ...

# %%
# !gdown https://drive.google.com/uc?id=1P6niKVo8VZpN9T_V6lbHYC7vEJvdp4WD
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1P6niKVo8VZpN9T_V6lbHYC7vEJvdp4WD
# To: /content/manualtestingData/13617862_2160_3840_30fps.mp4
# 100% 58.1M/58.1M [00:01<00:00, 33.2MB/s]

# %%
weightsPath="/content/peopledetection/People-Detection-8/runs/detect/train2/weights"
# !yolo task=detect mode=predict model={weightsPath}/best.pt conf=.25 source =myvideo2.mp4 save=True
# Out:
# Ultralytics 8.3.132 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/789) /content/manualtestingData/myvideo2.mp4: 640x384 6 persons, 67.9ms
# video 1/1 (frame 2/789) /content/manualtestingData/myvideo2.mp4: 640x384 6 persons, 23.6ms
# video 1/1 (frame 3/789) /content/manualtestingData/myvideo2.mp4: 640x384 6 persons, 25.0ms
# video 1/1 (frame 4/789) /content/manualtestingData/myvideo2.mp4: 640x384 6 persons, 27.1ms
# video 1/1 (frame 5/789) /content/manualtestingData/myvideo2.mp4: 640x384 6 persons, 16.6ms
# video 1/1 (frame 6/789) /content/manualtestingData/myvideo2.mp4: 640x384 5 persons, 15.3ms
# video 1/1 (frame 7/789) /content/manualtestingData/myvideo2.mp4: 640x384 6 persons, 15.1ms
# video 1/1 (frame 8/789) /content/manualtestingData/myvideo2.mp4: 640x384 6 persons, 27.6ms
# ...

# %%
# !gdown https://drive.google.com/uc?id=1EBbtT-vJvNM-3WmDgEFdE2kUxlVk5fnH
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1EBbtT-vJvNM-3WmDgEFdE2kUxlVk5fnH
# To: /content/manualtestingData/images.jpeg
# 100% 10.1k/10.1k [00:00<00:00, 37.0MB/s]

# %%
weightsPath="/content/peopledetection/People-Detection-8/runs/detect/train2/weights"
# !yolo task=detect mode=predict model={weightsPath}/best.pt conf=.25 source =images.jpeg save=True
# Out:
# Ultralytics 8.3.132 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/manualtestingData/images.jpeg: 448x640 3 persons, 50.6ms
# Speed: 3.7ms preprocess, 50.6ms inference, 141.9ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from google.colab import files
files.download('/content/manualtestingData/runs/detect/predict')
files.download('/content/manualtestingData/runs/detect/predict2')
files.download('/content/manualtestingData/runs/detect/predict3')

# %%
from ultralytics import YOLO

# Load your trained model, updating the path
model = YOLO('/content/peopledetection/People-Detection-8/runs/detect/train2/weights/best.pt')  # Corrected the path

# Save it explicitly (optional if already saved)
# model.export(format='pt')  # Already in YOLO format, 'pt' is not a valid format
# Use 'torchscript' instead to export to PyTorch format
model.export(format='torchscript')
# Out:
# Ultralytics 8.3.132 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.00GHz)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/peopledetection/People-Detection-8/runs/detect/train2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (5.9 MB)
#
# TorchScript: starting export with torch 2.6.0+cu124...
# TorchScript: export success ✅ 3.1s, saved as '/content/peopledetection/People-Detection-8/runs/detect/train2/weights/best.torchscript' (11.9 MB)
#
# Export complete (4.8s)
# Results saved to /content/peopledetection/People-Detection-8/runs/detect/train2/weights
# Predict:         yolo predict task=detect model=/content/peopledetection/People-Detection-8/runs/detect/train2/weights/best.torchscript imgsz=640
# Validate:        yolo val task=detect model=/content/peopledetection/People-Detection-8/runs/detect/train2/weights/best.torchscript imgsz=640 data=data.yaml
# ...
